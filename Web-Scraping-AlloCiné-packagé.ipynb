# %%
# %load_ext autoreload
# %autoreload 2

# %%
from scraping_lib import *

# %%
file_name = 'Liste-Films-Charlotte.xlsx'

# %% [markdown]
# # Séances films en commun

# %%
films = importer_fichier_films(file_name)

# %%
films_en_commun = trouver_films_commun(films)
# Out:
# Empty DataFrame
# Columns: [Title, Code]
# Index: []

# %%
toutes_les_séances = séances_films_en_commun(films_en_commun)
toutes_les_séances
# Out:
# Aucun film de la liste à l'affiche en ce moment dans un cinéma parisien

# %% [markdown]
# # Séance d'un autre film

# %%
films_allociné = scraping_films_allociné()
films_allociné
# Out:
#                                              Title    Code
# 0                        Super mario bros, le film  234099
# 1              Les trois mousquetaires: d'artagnan  288402
# 2                              La vie pour de vrai  297442
# 3    Donjons &amp; dragons : l'honneur des voleurs  221359
# 4                       10 jours encore sans maman  298509
# ..                                             ...     ...
# 205                                   Interstellar  114782
# 206                             Mad max: fury road  125054
# 207                                         Fritzi  264339
# 208                              Bonjour le monde!  273733
# 209                                          Music  276069
#
# [210 rows x 2 columns]

# %%
#exporter_films_allociné(films_allociné) # Pour obtenir le code du film souhaité
code = 288402 # Modifier le code selon le film souhaité
titre_séances = séances_film(code)
#exporter_film(titre_séances) 
titre_séances
# Out:
#                                   Titre                        Cinéma  \
# 0   Les trois mousquetaires: d'artagnan   MK2 Odéon (Côté St Michel)
# 1   Les trois mousquetaires: d'artagnan     Pathé Parnasse - Premium
# 2   Les trois mousquetaires: d'artagnan         UGC Ciné Cité Vélizy
# 3   Les trois mousquetaires: d'artagnan                   UGC Cyrano
# 4   Les trois mousquetaires: d'artagnan             Les 3 Luxembourg
# 5   Les trois mousquetaires: d'artagnan     Pathé Parnasse - Premium
# 6   Les trois mousquetaires: d'artagnan             Cinéma Studio 28
# 7   Les trois mousquetaires: d'artagnan             Les 3 Luxembourg
# 8   Les trois mousquetaires: d'artagnan     Pathé Parnasse - Premium
# 9   Les trois mousquetaires: d'artagnan             Les 3 Luxembourg
# 10  Les trois mousquetaires: d'artagnan     Pathé Parnasse - Premium
# 11  Les trois mousquetaires: d'artagnan         UGC Ciné Cité Vélizy
# 12  Les trois mousquetaires: d'artagnan             Les 3 Luxembourg
# 13  Les trois mousquetaires: d'artagnan     Pathé Parnasse - Premium
# 14  Les trois mousquetaires: d'artagnan         UGC Ciné Cité Vélizy
# 15  Les trois mousquetaires: d'artagnan             Les 3 Luxembourg
# 16  Les trois mousquetaires: d'artagnan     Pathé Parnasse - Premium
# 17  Les trois mousquetaires: d'artagnan         UGC Ciné Cité Vélizy
# 18  Les trois mousquetaires: d'artagnan             Les 3 Luxembourg
# 19  Les trois mousquetaires: d'artagnan     Pathé Parnasse - Premium
#
#                                               Adresse  \
# 0                     7, rue Hautefeuille 75006 Paris
# 1                         3, rue d'Odessa 75014 Paris
# 2   Centre commercial Régional Vélizy 2 78140 Véli...
# 3                      7, rue Rameau 78000 Versailles
# 4             67 , rue Monsieur Le Prince 75006 Paris
# 5                         3, rue d'Odessa 75014 Paris
# 6                         10, rue Tholoze 75018 Paris
# 7             67 , rue Monsieur Le Prince 75006 Paris
# 8                         3, rue d'Odessa 75014 Paris
# 9             67 , rue Monsieur Le Prince 75006 Paris
# 10                        3, rue d'Odessa 75014 Paris
# 11  Centre commercial Régional Vélizy 2 78140 Véli...
# 12            67 , rue Monsieur Le Prince 75006 Paris
# 13                        3, rue d'Odessa 75014 Paris
# 14  Centre commercial Régional Vélizy 2 78140 Véli...
# 15            67 , rue Monsieur Le Prince 75006 Paris
# 16                        3, rue d'Odessa 75014 Paris
# 17  Centre commercial Régional Vélizy 2 78140 Véli...
# 18            67 , rue Monsieur Le Prince 75006 Paris
# 19                        3, rue d'Odessa 75014 Paris
#
#                                                 Infos
# 0   {'Date&Version': [' 11 juillet 2023 En VF'], '...
# 1   {'Date&Version': [' 11 juillet 2023 En VF'], '...
# 2   {'Date&Version': [' 11 juillet 2023 En VF'], '...
# 3   {'Date&Version': [' 11 juillet 2023 En VF'], '...
# 4   {'Date&Version': [' 12 juillet 2023 En VF'], '...
# 5   {'Date&Version': [' 12 juillet 2023 En VF'], '...
# 6   {'Date&Version': [' 12 juillet 2023 En VF'], '...
# 7   {'Date&Version': [' 13 juillet 2023 En VF'], '...
# 8   {'Date&Version': [' 13 juillet 2023 En VF'], '...
# 9   {'Date&Version': [' 14 juillet 2023 En VF'], '...
# 10  {'Date&Version': [' 14 juillet 2023 En VF'], '...
# 11  {'Date&Version': [' 14 juillet 2023 En VF'], '...
# 12  {'Date&Version': [' 15 juillet 2023 En VF'], '...
# 13  {'Date&Version': [' 15 juillet 2023 En VF'], '...
# 14  {'Date&Version': [' 15 juillet 2023 En VF'], '...
# 15  {'Date&Version': [' 16 juillet 2023 En VF'], '...
# 16  {'Date&Version': [' 16 juillet 2023 En VF'], '...
# 17  {'Date&Version': [' 16 juillet 2023 En VF'], '...
# 18  {'Date&Version': [' 17 juillet 2023 En VF'], '...
# 19  {'Date&Version': [' 17 juillet 2023 En VF'], '...
